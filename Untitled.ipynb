# %%
import pandas as pd
import numpy as np

# %matplotlib inline

import seaborn as sns
import pylab as plt
import seaborn as sns

# %%
data=pd.read_excel('../technical_challenge_DA/data/measurements2.xlsx')
data
# Out:
#      distance  consume  speed  temp_inside  temp_outside specials gas_type  \
# 0        28.0      5.0     26         21.5            12      NaN      E10
# 1        12.0      4.2     30         21.5            13      NaN      E10
# 2        11.2      5.5     38         21.5            15      NaN      E10
# 3        12.9      3.9     36         21.5            14      NaN      E10
# 4        18.5      4.5     46         21.5            15      NaN      E10
# ..        ...      ...    ...          ...           ...      ...      ...
# 383      16.0      3.7     39         24.5            18      NaN     SP98
# 384      16.1      4.3     38         25.0            31       AC     SP98
# 385      16.0      3.8     45         25.0            19      NaN     SP98
# 386      15.4      4.6     42         25.0            31       AC     SP98
# 387      14.7      5.0     25         25.0            30       AC     SP98
#
#      AC  rain  sun  refill liters refill gas
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   distance       388 non-null    float64
#  1   consume        388 non-null    float64
#  2   speed          388 non-null    int64
#  3   temp_inside    376 non-null    float64
#  4   temp_outside   388 non-null    int64
#  5   specials       93 non-null     object
#  6   gas_type       388 non-null    object
#  7   AC             388 non-null    int64
#  8   rain           388 non-null    int64
#  9   sun            388 non-null    int64
#  10  refill liters  13 non-null     float64
#  11  refill gas     13 non-null     object
# dtypes: float64(4), int64(5), object(3)
# memory usage: 36.5+ KB

# %%
data.AC.value_counts()
# Out:
# 0    358
# 1     30
# Name: AC, dtype: int64

# %%
data.gas_type.value_counts()
# Out:
# SP98    228
# E10     160
# Name: gas_type, dtype: int64

# %%
plt.figure(figsize=(15, 10))

sns.set(style='white')

mask=np.triu(np.ones_like(data.corr(), dtype=bool))

cmap=sns.diverging_palette(0, 10, as_cmap=True)


sns.heatmap(data.corr(),
           mask=mask,
          cmap=cmap,
          center=0,
          square=True,
          annot=True,
          linewidths=0.5,
          cbar_kws={'shrink': 0.5});

# %%
data=data.assign(Precio=1)
data
# Out:
#      distance  consume  speed  temp_inside  temp_outside specials gas_type  \
# 0        28.0      5.0     26         21.5            12      NaN      E10
# 1        12.0      4.2     30         21.5            13      NaN      E10
# 2        11.2      5.5     38         21.5            15      NaN      E10
# 3        12.9      3.9     36         21.5            14      NaN      E10
# 4        18.5      4.5     46         21.5            15      NaN      E10
# ..        ...      ...    ...          ...           ...      ...      ...
# 383      16.0      3.7     39         24.5            18      NaN     SP98
# 384      16.1      4.3     38         25.0            31       AC     SP98
# 385      16.0      3.8     45         25.0            19      NaN     SP98
# 386      15.4      4.6     42         25.0            31       AC     SP98
# 387      14.7      5.0     25         25.0            30       AC     SP98
#
#      AC  rain  sun  refill liters refill gas  Precio
# ...

# %%
precio=[]

for i in data.gas_type:
    if i == 'E10':
        precio.append(1.38)
    elif i == 'SP98':
        precio.append(1.46)
precio[:5]
# Out:
# [1.38, 1.38, 1.38, 1.38, 1.38]

# %%
data.Precio=precio
data
# Out:
#      distance  consume  speed  temp_inside  temp_outside specials gas_type  \
# 0        28.0      5.0     26         21.5            12      NaN      E10
# 1        12.0      4.2     30         21.5            13      NaN      E10
# 2        11.2      5.5     38         21.5            15      NaN      E10
# 3        12.9      3.9     36         21.5            14      NaN      E10
# 4        18.5      4.5     46         21.5            15      NaN      E10
# ..        ...      ...    ...          ...           ...      ...      ...
# 383      16.0      3.7     39         24.5            18      NaN     SP98
# 384      16.1      4.3     38         25.0            31       AC     SP98
# 385      16.0      3.8     45         25.0            19      NaN     SP98
# 386      15.4      4.6     42         25.0            31       AC     SP98
# 387      14.7      5.0     25         25.0            30       AC     SP98
#
#      AC  rain  sun  refill liters refill gas  Precio
# ...

# %%
plt.figure(figsize=(15, 10))

sns.set(style='white')

mask=np.triu(np.ones_like(data.corr(), dtype=bool))

cmap=sns.diverging_palette(0, 10, as_cmap=True)


sns.heatmap(data.corr(),
           mask=mask,
          cmap=cmap,
          center=0,
          square=True,
          annot=True,
          linewidths=0.5,
          cbar_kws={'shrink': 0.5});

# %%
data=data.assign(consumo_litro=data.distance*data.consume/100)
data
# Out:
#      distance  consume  speed  temp_inside  temp_outside specials gas_type  \
# 0        28.0      5.0     26         21.5            12      NaN      E10
# 1        12.0      4.2     30         21.5            13      NaN      E10
# 2        11.2      5.5     38         21.5            15      NaN      E10
# 3        12.9      3.9     36         21.5            14      NaN      E10
# 4        18.5      4.5     46         21.5            15      NaN      E10
# ..        ...      ...    ...          ...           ...      ...      ...
# 383      16.0      3.7     39         24.5            18      NaN     SP98
# 384      16.1      4.3     38         25.0            31       AC     SP98
# 385      16.0      3.8     45         25.0            19      NaN     SP98
# 386      15.4      4.6     42         25.0            31       AC     SP98
# 387      14.7      5.0     25         25.0            30       AC     SP98
#
#      AC  rain  sun  refill liters refill gas  Precio  consumo_litro
# ...

# %%
data=data.assign(precio_litro=data.Precio*data.consumo_litro)
data
# Out:
#      distance  consume  speed  temp_inside  temp_outside specials gas_type  \
# 0        28.0      5.0     26         21.5            12      NaN      E10
# 1        12.0      4.2     30         21.5            13      NaN      E10
# 2        11.2      5.5     38         21.5            15      NaN      E10
# 3        12.9      3.9     36         21.5            14      NaN      E10
# 4        18.5      4.5     46         21.5            15      NaN      E10
# ..        ...      ...    ...          ...           ...      ...      ...
# 383      16.0      3.7     39         24.5            18      NaN     SP98
# 384      16.1      4.3     38         25.0            31       AC     SP98
# 385      16.0      3.8     45         25.0            19      NaN     SP98
# 386      15.4      4.6     42         25.0            31       AC     SP98
# 387      14.7      5.0     25         25.0            30       AC     SP98
#
# ...

# %%
data.groupby('gas_type').mean()
# Out:
#            distance   consume      speed  temp_inside  temp_outside        AC  \
# gas_type
# E10       21.096250  4.931250  43.506250    21.917197      10.11875  0.043750
# SP98      18.639912  4.899123  40.820175    21.938356      12.22807  0.100877
#
#               rain       sun  refill liters  Precio  consumo_litro  \
# gas_type
# E10       0.100000  0.075000        39.6000    1.38       1.008933
# SP98      0.140351  0.087719        35.5625    1.46       0.883618
#
#           precio_litro
# gas_type
# E10           1.392327
# SP98          1.290083

# %% [markdown]
# El tipo E10 tiene un consumo por litro mayor y un precio menor, pero la media consumida y precio es mayor que el SP98.
